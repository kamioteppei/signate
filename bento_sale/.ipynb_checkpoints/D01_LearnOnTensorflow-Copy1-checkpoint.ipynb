# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.model_selection import cross_validate
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import seaborn as sns

# %%
train_df = pd.read_csv("./C01_train_encoded.csv")
#train_df.info()

# %%
train_df.head(10)
# Out:
#      datetime      y  dateinterval  dayofmonth  weekofyear  dayofweek  \
# 0  2013-11-18   90.0           1.0          18          47          0
# 1  2013-11-19  101.0           2.0          19          47          1
# 2  2013-11-20  118.0           3.0          20          47          2
# 3  2013-11-21  120.0           4.0          21          47          3
# 4  2013-11-22  130.0           5.0          22          47          4
# 5  2013-11-25  135.0           8.0          25          48          0
# 6  2013-11-26  145.0           9.0          26          48          1
# 7  2013-11-27  140.0          10.0          27          48          2
# 8  2013-11-28  151.0          11.0          28          48          3
# 9  2013-11-29  116.0          12.0          29          48          4
#
#    soldout  kcal_fill_median  kcal_fill_mean  remarks  event  payday  weather  \
# 0        0             412.0      407.381188        0      0     0.0      1.0
# 1        1             412.0      407.381188        0      0     0.0      1.0
# 2        0             412.0      407.381188        0      0     0.0      1.0
# 3        1             412.0      407.381188        0      0     0.0      1.0
# 4        1             412.0      407.381188        0      0     0.0      1.0
# 5        1             412.0      407.381188        0      0     0.0      4.0
# 6        0             412.0      407.381188        0      0     0.0      1.0
# 7        1             412.0      407.381188        0      0     0.0      2.0
# 8        0             412.0      407.381188        0      0     0.0      3.0
# 9        0             412.0      407.381188        0      0     0.0      1.0
#
#    precipitation  temperature
# 0            0.0         19.8
# 1            0.0         17.0
# 2            0.0         15.5
# 3            0.0         15.2
# 4            0.0         16.1
# 5            0.0         14.6
# 6            0.0         17.9
# 7            0.0         14.7
# 8            0.0         17.7
# 9            0.0         12.1

# %%
train_data = train_df.values
train_X = train_data[:, 2:]  # id,正解データ列以外を抽出
train_Y = train_data[:, 1]  # 正解データ列のみ抽出

valid_X = train_data[:, 2:]  # id,正解データ列以外を抽出
valid_Y = train_data[:, 1]  # 正解データ列のみ抽出

# %%
train_X.shape
# Out:
# (207, 13)

# %%
train_Y.shape
# Out:
# (207,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

model = Sequential()
model.add(Dense(128, input_dim=train_X.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1))

model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['accuracy'])

model.fit(train_X, train_Y, epochs=2000, verbose=0)
loss, accuracy = model.evaluate(valid_X, valid_Y)
print("loss = {:.2f}".format(loss))
print("acc = {:.2f}".format(accuracy))
# Out:
# 207/207 [==============================] - 0s 405us/step
# loss = 225.66
# acc = 0.00

# %%
valid_Y_pred = model.predict(valid_X, verbose=1)
# Out:
# 207/207 [==============================] - 0s 287us/step

# %%
valid_Y_pred[:,0]
# Out:
# array([141.82425 , 134.95299 , 128.26132 , 122.62475 , 121.37098 ,
#        140.8184  , 128.48216 , 122.58689 , 116.43322 , 113.24228 ,
#        152.93352 , 142.70232 , 133.63762 , 124.59567 , 123.11278 ,
#        151.28008 , 147.04234 , 129.1241  , 118.5713  , 115.14692 ,
#        139.16095 , 135.8843  , 124.3242  , 120.936485, 107.476364,
#        121.745804, 115.35584 , 108.53799 , 130.06013 , 126.86353 ,
#        113.27466 , 110.531456, 121.6255  , 123.565994, 105.02841 ,
#        102.620094, 123.50319 , 117.66939 , 108.29245 ,  97.08996 ,
#        101.624435, 120.81717 , 109.54577 , 104.60524 ,  97.926186,
#         96.163246, 130.36543 , 133.26419 , 116.9924  , 110.039406,
#         97.17182 , 129.74702 , 108.300735, 100.82513 ,  98.38885 ,
#        115.474075, 110.079926,  97.99149 ,  93.17534 ,  99.341705,
#        112.70647 ,  95.85165 ,  85.72701 ,  89.12024 ,  83.7784  ,
#        123.3187  , 112.181656, 115.42252 ,  91.70014 ,  82.61336 ,
#        114.97319 , 101.35762 ,  84.5679  ,  82.322105,  73.33293 ,
#         97.904976,  87.9993  ,  83.308075,  89.65135 ,  84.249214,
#         83.55025 ,  76.64244 ,  69.93068 , 102.671165,  78.68781 ,
#         94.38644 ,  83.013435,  87.21905 ,  68.84719 ,  97.77616 ,
#         79.8253  ,  75.36801 ,  75.004555,  99.77901 ,  83.86078 ,
#         75.53411 ,  65.965996,  64.88574 ,  58.63301 ,  90.05103 ,
#         73.3034  ,  65.45072 ,  65.60739 ,  95.10502 ,  69.12521 ,
#         66.84463 ,  73.19682 ,  71.541985,  72.43186 ,  67.803734,
#         74.01321 ,  77.38002 ,  79.20895 ,  71.3461  ,  65.05211 ,
#         88.19284 ,  80.11872 ,  70.62665 ,  97.40963 ,  86.86696 ,
#         62.502365,  71.59042 ,  68.15448 ,  66.77806 ,  68.43007 ,
#         88.36375 ,  73.62676 ,  68.64418 ,  67.29835 ,  60.149918,
#         84.66608 ,  74.748726,  68.64539 ,  72.25719 ,  63.841373,
#         91.339554,  69.00437 ,  65.47226 ,  83.608444,  63.454544,
#         59.749794,  64.45429 ,  63.45001 ,  60.239864,  59.768208,
#         73.10683 ,  64.90658 ,  58.302982,  57.401665,  59.039867,
#         58.4658  ,  67.19543 ,  57.48757 ,  76.66111 ,  58.60737 ,
#         89.28443 ,  61.276886,  52.76972 ,  61.274963,  56.247765,
#         55.268932,  58.88131 ,  53.905807,  57.45185 ,  83.78559 ,
#         60.868027,  61.513493,  60.049232,  55.17281 ,  56.31686 ,
#         58.207424,  57.36314 ,  57.409515,  56.08272 ,  83.4042  ,
#         57.251026,  54.27182 ,  54.66383 ,  54.027073,  74.42438 ,
#         48.617054,  76.75963 ,  54.385685,  52.047543,  52.481865,
#         50.228794,  50.942223,  58.361465,  82.59753 ,  51.928574,
#         51.36963 ,  49.463852,  55.99782 ,  56.66996 ,  56.862022,
#         48.69866 ,  68.46195 ,  54.581257,  67.42108 ,  49.349648,
#         49.51045 ,  50.80338 ,  50.709774,  49.034122,  72.005615,
#         51.53268 ,  50.45272 ], dtype=float32)

# %%
data = pd.DataFrame()
data['datetime'] = train_df['datetime']
data['valid_Y'] = train_df['y']
data['valid_Y_pred'] = pd.Series(valid_Y_pred[:,0], name = 'valid_Y_pred')

plt.rcParams['figure.figsize'] = (15.0, 15.0)
plt.plot( 'datetime', 'valid_Y'     , data=data, color='skyblue')
plt.plot( 'datetime', 'valid_Y_pred', data=data, color='olive')
plt.legend()

# %%
test_df = pd.read_csv("./C01_test_encoded.csv")
#test_df.info()

# %%
test_df.head(5)
# Out:
#      datetime   y  dateinterval  dayofmonth  weekofyear  dayofweek  soldout  \
# 0  2014-10-01 NaN         318.0           1          92          2        1
# 1  2014-10-02 NaN         319.0           2          92          3        0
# 2  2014-10-03 NaN         320.0           3          92          4        0
# 3  2014-10-06 NaN         323.0           6          93          0        1
# 4  2014-10-07 NaN         324.0           7          93          1        0
#
#    kcal_fill_median  kcal_fill_mean  remarks  event  payday  weather  \
# 0             420.0           420.0        0      0     0.0      8.0
# 1             415.0           415.0        0      0     0.0      4.0
# 2             405.0           405.0        0      0     0.0      2.0
# 3             400.0           400.0        0      0     0.0      8.0
# 4             430.0           430.0        0      0     0.0      2.0
#
#    precipitation  temperature
# 0            0.0         20.2
# 1            0.0         23.9
# 2            0.0         28.7
# 3            0.5         21.5
# 4            0.0         22.1

# %%
test_data = test_df.values
X_test = test_data[:, 2:]

# %%
Y_test = model.predict(X_test, verbose=1)
#y_test = model.predict_proba(xs_test, batch_size=1000, verbose=1)
# Out:
# 40/40 [==============================] - 0s 210us/step

# %%
Y_test.shape
# Out:
# (40, 1)

# %%
Y_test[0:20,:]
# Out:
# array([[53.386646],
#        [49.767628],
#        [49.35453 ],
#        [60.27788 ],
#        [52.17269 ],
#        [50.423435],
#        [46.075832],
#        [66.76435 ],
#        [49.926903],
#        [69.44565 ],
#        [47.68604 ],
#        [46.682934],
#        [51.906246],
#        [50.27652 ],
#        [49.588554],
#        [49.47059 ],
#        [58.530464],
#        [49.515594],
#        [50.132523],
#        [49.99122 ]], dtype=float32)

# %%
data2 = pd.DataFrame()
data2['datetime'] = test_df['datetime']
data2['valid_Y_pred'] = pd.Series(Y_test[:,0], name = 'valid_Y_pred')

data3 = pd.concat([data, data2], axis=0, sort=False)
data3[190:210]
# Out:
#        datetime  valid_Y  valid_Y_pred
# 190  2014-09-04     54.0     51.369629
# 191  2014-09-05     43.0     49.463852
# 192  2014-09-08     68.0     55.997822
# 193  2014-09-09     63.0     56.669960
# 194  2014-09-10     54.0     56.862022
# 195  2014-09-11     53.0     48.698662
# 196  2014-09-12    115.0     68.461952
# 197  2014-09-16     56.0     54.581257
# 198  2014-09-17     49.0     67.421082
# 199  2014-09-18     46.0     49.349648
# 200  2014-09-19     45.0     49.510448
# 201  2014-09-22     29.0     50.803379
# 202  2014-09-24     59.0     50.709774
# 203  2014-09-25     50.0     49.034122
# 204  2014-09-26     45.0     72.005615
# 205  2014-09-29     56.0     51.532681
# 206  2014-09-30     40.0     50.452721
# 0    2014-10-01      NaN     53.386646
# 1    2014-10-02      NaN     49.767628
# 2    2014-10-03      NaN     49.354530

# %%
plt.rcParams['figure.figsize'] = (15.0, 15.0)
plt.plot( 'datetime', 'valid_Y'     , data=data3, color='skyblue')
plt.plot( 'datetime', 'valid_Y_pred', data=data3, color='olive')
plt.legend()

# %%
Submission = pd.DataFrame()
Submission["datetime"] = test_df["datetime"].astype(str)
Submission["y"] = Y_test.astype(int)

# %%
import csv
Submission.to_csv("D01_Submission_2.csv", index=False)
