# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.model_selection import cross_validate
from xgboost import XGBClassifier
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import seaborn as sns

# %%
train_df = pd.read_csv("./Data/resources.csv")
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1541272 entries, 0 to 1541271
# Data columns (total 4 columns):
# id             1541272 non-null object
# description    1540980 non-null object
# quantity       1541272 non-null int64
# price          1541272 non-null float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 47.0+ MB

# %%
total_price = pd.Series(train_df['quantity'].fillna(0.0).astype(int) * train_df['price'].fillna(0.0).astype(float))
total_price = total_price.rename('total_price', axis='columns')
total_price.head(10)
# Out:
# 0    149.00
# 1     44.85
# 2      8.45
# 3     27.18
# 4     74.85
# 5     16.99
# 6      9.95
# 7     20.22
# 8     19.90
# 9     18.04
# Name: total_price, dtype: float64

# %%
train_df = pd.concat([train_df, total_price], axis=1)
train_df.head(10)
# Out:
#         id                                        description  quantity  \
# 0  p233245  LC652 - Lakeshore Double-Space Mobile Drying Rack         1
# 1  p069063        Bouncy Bands for Desks (Blue support pipes)         3
# 2  p069063  Cory Stories: A Kid's Book About Living With Adhd         1
# 3  p069063  Dixon Ticonderoga Wood-Cased #2 HB Pencils, Bo...         2
# 4  p069063  EDUCATIONAL INSIGHTS FLUORESCENT LIGHT FILTERS...         3
# 5  p069063  Last to Finish: A Story About the Smartest Boy...         1
# 6  p069063  Mrs. Gorski, I Think I Have the Wiggle Fidgets...         1
# 7  p069063  See-N-Read 1503905CQ Reading Tool - Book Size,...         2
# 8  p096795  Brewster WPD90218 Wall Pops Flirt Dot, Set of ...         2
# 9  p096795  Brewster Wall Pops WPE99065 Peel & Stick Calyp...         2
#
#     price  total_price
# 0  149.00       149.00
# 1   14.95        44.85
# 2    8.45         8.45
# 3   13.59        27.18
# 4   24.95        74.85
# 5   16.99        16.99
# 6    9.95         9.95
# 7   10.11        20.22
# 8    9.95        19.90
# 9    9.02        18.04

# %%
train_df['description'] = train_df['description'].replace('\n','', regex=True).replace(',','').replace('"','')
#apply(lambda d: d.str.strip())

# %%
grouped_by_id = train_df.groupby('id')
grouped_by_id.size().head(10)
# Out:
# id
# p000001     4
# p000002    14
# p000003     4
# p000004    95
# p000005     4
# p000006     5
# p000007     1
# p000008    80
# p000009    38
# p000010     1
# dtype: int64

# %%
import functools

def f_reduce_sum(list):
    val = functools.reduce(lambda x, y: x + y, list)
    return round(val, 2)

def f_reduce_concat(list):
    return functools.reduce(lambda x, y: str(x) + ' ' 
                                       + str(y)
                           , list)

# %%
train_df_grp1 = grouped_by_id.count()
train_df_grp1.head(10)
# Out:
#          description  quantity  price  total_price
# id
# p000001            4         4      4            4
# p000002           14        14     14           14
# p000003            4         4      4            4
# p000004           95        95     95           95
# p000005            4         4      4            4
# p000006            5         5      5            5
# p000007            1         1      1            1
# p000008           80        80     80           80
# p000009           38        38     38           38
# p000010            1         1      1            1

# %%
train_df_grp2 = grouped_by_id.agg({
            'description': f_reduce_concat,
            'quantity': f_reduce_sum,
            'total_price': f_reduce_sum
            })
train_df_grp2.head(10)
# Out:
#                                                description  quantity  \
# id
# p000001  Cap Barbell 300 Pound Olympic Set, Grey Cap Ba...         7
# p000002  10 Sony Headphones (BUY 9 GET 1 FREE) Belkin 6...        21
# p000003  EE820X - Phonemic Awareness Instant Learning C...         4
# p000004  A Bad Case of the Giggles Poems That Will Make...        98
# p000005  Fitbit Zip Wireless Activity Tracker, Lime Fit...         8
# p000006  Danny and the Dinosaur: 50th Anniversary Editi...         5
# p000007  HP Chromebook 11 G4 11.6 Inch Laptop (Intel N2...         6
# p000008  A Whale of a Tale Alvin and the Chipmunks Alvi...        80
# p000009  Ball Don't Lie Baseball Card Adventure (4 Bk S...        45
# p000010  Easy Spanish Reader Premium, Third Edition: A ...        30
#
#          total_price
# id
# p000001       833.63
# p000002       630.28
# p000003       298.97
# p000004      1126.22
# p000005       702.31
# p000006       130.62
# p000007       947.88
# p000008       296.99
# p000009       335.40
# p000010       332.40

# %%
train_df_grp2['cnt_by_id'] = train_df_grp1['quantity']

# %%
train_df_grp2 = train_df_grp2.rename({'quantity':'total_quantity'}, axis='columns')
train_df_grp2
# Out:
#                                                description  total_quantity  \
# id
# p000001  Cap Barbell 300 Pound Olympic Set, Grey Cap Ba...               7
# p000002  10 Sony Headphones (BUY 9 GET 1 FREE) Belkin 6...              21
# p000003  EE820X - Phonemic Awareness Instant Learning C...               4
# p000004  A Bad Case of the Giggles Poems That Will Make...              98
# p000005  Fitbit Zip Wireless Activity Tracker, Lime Fit...               8
# p000006  Danny and the Dinosaur: 50th Anniversary Editi...               5
# p000007  HP Chromebook 11 G4 11.6 Inch Laptop (Intel N2...               6
# p000008  A Whale of a Tale Alvin and the Chipmunks Alvi...              80
# p000009  Ball Don't Lie Baseball Card Adventure (4 Bk S...              45
# p000010  Easy Spanish Reader Premium, Third Edition: A ...              30
# p000011            Dixon Ticonderoga Pencils, No. 2, 96/Pk              20
# p000012  Big Joe Cube /w Ottoman in Smartmax, Black Qua...               2
# p000013  Balance Buddy Bolster Swing For OntheGo 3 Swin...               4
# p000014               Classic Royal Reading Writing Center               1
# p000015             Apple - iPad Air 2 Wi-Fi 32GB - Silver               1
# p000016  Scholastic News, Grade 4 (min. 10 subscription...              60
# p000017  Wire Mesh Wall Mounted or Freestanding Documen...              16
# p000018  DD358 - Cells & Organisms Activity Tub - Gr. 4...               2
# p000019  Ozobot Evo Starter Pack, the STEM Robot Toy wi...              12
# p000020  Lenovo N22 Chromebook 80SF - 11.6' - Celeron N...               5
# p260115  Samsung Chromebook 3 XE500C13-K01US 2 GB RAM 1...               2
#
#          total_price  cnt_by_id
# id
# p000001       833.63          4
# p000002       630.28         14
# p000003       298.97          4
# p000004      1126.22         95
# p000005       702.31          4
# p000006       130.62          5
# p000007       947.88          1
# p000008       296.99         80
# p000009       335.40         38
# p000010       332.40          1
# p000011       251.80          1
# p000012       135.98          2
# p000013      2626.63          4
# p000014       300.78          1
# p000015       399.99          1
# p000016       187.20          2
# p000017       367.84          1
# p000018       474.05          2
# p000019       934.26          3
# p000020       741.95          1
# p000021       101.17          6
# p000022       116.00          1
# p000023       539.97          1
# p000024       471.90          1
# p000025       362.25          4
# p000026       461.97         27
# p000027       823.98         12
# p000028       637.74          2
# p000029       865.95          4
# p000030       424.81          3
# ...              ...        ...
# p260086       871.95          2
# p260087       379.94          4
# p260088       107.16          7
# p260089       157.65         14
# p260090       214.08          8
# p260091      1259.55          2
# p260092       214.75          3
# p260093       955.74          2
# p260094       487.63         11
# p260095       485.32         11
# p260096       367.96          6
# p260097       599.94          3
# p260098      2743.58          4
# p260099       243.42          4
# p260100       157.28          4
# p260101       405.84          7
# p260102       314.00          1
# p260103       339.00          1
# p260104       702.96          2
# p260105       294.06          9
# p260106       129.02          1
# p260107       497.58         12
# p260108       581.08          8
# p260109       317.98          1
# p260110       449.97          1
# p260111       176.08         27
# p260112       119.37          2
# p260113       811.49          3
# p260114       749.27         10
# p260115       318.97          2
#
# [260115 rows x 4 columns]

# %%
train_df_grp2.head(10)
# Out:
#                                                description  total_quantity  \
# id
# p000001  Cap Barbell 300 Pound Olympic Set, Grey Cap Ba...               7
# p000002  10 Sony Headphones (BUY 9 GET 1 FREE) Belkin 6...              21
# p000003  EE820X - Phonemic Awareness Instant Learning C...               4
# p000004  A Bad Case of the Giggles Poems That Will Make...              98
# p000005  Fitbit Zip Wireless Activity Tracker, Lime Fit...               8
# p000006  Danny and the Dinosaur: 50th Anniversary Editi...               5
# p000007  HP Chromebook 11 G4 11.6 Inch Laptop (Intel N2...               6
# p000008  A Whale of a Tale Alvin and the Chipmunks Alvi...              80
# p000009  Ball Don't Lie Baseball Card Adventure (4 Bk S...              45
# p000010  Easy Spanish Reader Premium, Third Edition: A ...              30
#
#          total_price  cnt_by_id
# id
# p000001       833.63          4
# p000002       630.28         14
# p000003       298.97          4
# p000004      1126.22         95
# p000005       702.31          4
# p000006       130.62          5
# p000007       947.88          1
# p000008       296.99         80
# p000009       335.40         38
# p000010       332.40          1

# %%
import csv
train_df_grp2.to_csv("B01.csv", index=True, quoting=csv.QUOTE_NONNUMERIC , quotechar='"')

# %%
#dummy_df = pd.read_csv("B01_dummy.csv")
#dummy_df.info()
